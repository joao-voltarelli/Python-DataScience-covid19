# %%
import numpy as np
from sklearn.cluster import KMeans
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
from sklearn.preprocessing import scale
seaborn.set()
# %matplotlib inline

data = pd.read_csv("COVID19_state.csv")
data.drop(['State','Sex Ratio', 'Smoking Rate', 'Flu Deaths', 'Respiratory Deaths', 'Physicians', 'Pollution', 'Med-Large Airports', 'Temperature', 'Urban', 'Age 0-25', 'Age 26-54', 'Age 55+', 'School Closure Date'], axis=1, inplace=True)

data.head()

'''
#GRAFICO PARA OBSERVAR QUAL SERIA O VALOR DE K IDEAL

inertia = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i, random_state=1234)
    kmeans.fit(data)
    inertia.append((i,kmeans.inertia_,))
    
plt.plot([w[0] for w in inertia],[w[1] for w in inertia], marker="X")
'''
'''
wcss = []
 
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'random')
    kmeans.fit(data)
    print (i,kmeans.inertia_)
    wcss.append(kmeans.inertia_)  
plt.plot(range(1, 11), wcss)
plt.title('O Metodo Elbow')
plt.xlabel('Numero de Clusters')
plt.ylabel('WSS') #within cluster sum of squares
plt.show()
'''

'''
kmeans = KMeans(n_clusters=4, init='k-means++', n_init=10, random_state=1234)
kmeans.fit(data)
cluster_list = kmeans.labels_
data["clusters"] = cluster_list
data.groupby("clusters").aggregate("mean").plot.bar()
plt.title("Gastos por cluster")
'''
# Out:
# '\nkmeans = KMeans(n_clusters=4, init=\'k-means++\', n_init=10, random_state=1234)\nkmeans.fit(data)\ncluster_list = kmeans.labels_\ndata["clusters"] = cluster_list\ndata.groupby("clusters").aggregate("mean").plot.bar()\nplt.title("Gastos por cluster")\n'

# %%
# Out:
# array([[1.78498667e+05, 2.06498333e+04, 1.04416667e+03, 5.81007200e+06,
#         1.87629800e+02, 4.57666667e-01, 1.36233333e+03, 5.27101667e+04,
#         5.86381667e+04, 3.06666667e+00, 9.83333333e+01, 8.06616667e+03],
#        [2.02894000e+05, 1.93862857e+04, 9.16428571e+02, 3.15761643e+06,
#         1.45577857e+02, 4.59042857e-01, 7.15285714e+02, 4.96662857e+04,
#         5.48391429e+04, 3.52857143e+00, 8.20000000e+01, 7.63714286e+03],
#        [1.66857400e+05, 1.29396000e+04, 7.52400000e+02, 4.46188140e+06,
#         8.41719000e+01, 4.77560000e-01, 1.18740000e+03, 4.51382000e+04,
#         5.06550000e+04, 3.72000000e+00, 1.10000000e+02, 7.75420000e+03],
#        [2.31771667e+05, 4.02190000e+04, 2.55333333e+03, 6.87317567e+06,
#         4.16663767e+02, 4.70100000e-01, 1.79866667e+03, 5.46326667e+04,
#         6.38616667e+04, 3.10000000e+00, 1.07333333e+02, 8.74366667e+03],
#        [8.42719500e+05, 5.00865000e+04, 1.81950000e+03, 3.47048920e+07,
# ...

# %%
distance = kmeans.fit_transform(data)
distance
# Out:
# array([[1.18162980e+06, 1.07087866e+07, 5.20881862e+05, 2.52844242e+06,
#         7.45338538e+06, 3.98101908e+06, 2.00106675e+07, 3.39804963e+07,
#         5.55241407e+06, 5.59544647e+04],
#        [2.99575877e+06, 6.53245602e+06, 3.65630524e+06, 1.65184195e+06,
#         3.27713177e+06, 1.95791728e+05, 1.58358097e+07, 2.98041833e+07,
#         1.37623113e+06, 4.15271115e+06],
#        [1.12570873e+06, 8.40318066e+06, 1.78563104e+06, 2.41638209e+05,
#         5.14775760e+06, 1.67534357e+06, 1.77060131e+07, 3.16747960e+07,
#         3.24685392e+06, 2.28270032e+06],
#        [5.46639644e+06, 4.06201830e+06, 6.12690324e+06, 4.12131231e+06,
#         8.07007968e+05, 2.66621930e+06, 1.33668431e+07, 2.73335119e+07,
#         1.09510120e+06, 6.62323888e+06],
#        [3.80442956e+07, 2.85165041e+07, 3.87051422e+07, 3.66981105e+07,
#         3.17720969e+07, 3.52443250e+07, 1.92229488e+07, 5.25621300e+06,
#         3.36728738e+07, 3.92008707e+07],
# ...
